# %%
# import 
import os
import pandas as pd

# %%
# read json
df = pd.read_json('./temp/prayers.json')

display(df)
# Out:
#       name                                        description  order  \
# 0     Fajr               Dawn prayer performed before sunrise      1
# 1    Dhuhr  Midday prayer performed after the sun passes i...      2
# 2      Asr   Afternoon prayer performed in the late afternoon      3
# 3  Maghrib          Sunset prayer performed just after sunset      4
# 4     Isha  Night prayer performed after twilight has disa...      5
#
#   start_hour  end_hour
# 0   05:00:00  06:00:00
# 1   12:00:00  13:00:00
# 2   15:00:00  16:00:00
# 3   18:00:00  19:00:00
# 4   19:00:00  00:00:00
